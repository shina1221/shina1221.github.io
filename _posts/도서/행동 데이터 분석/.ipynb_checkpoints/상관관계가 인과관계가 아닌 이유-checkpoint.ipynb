# %%
import pandas as pd 
import numpy as np 
stand_data =pd.read_csv('./BehavioralDataAnalysis-master/Chapter 1 - The causal-behavioral framework for data analysis/chap1-stand_data.csv')

# %%
type(stand_data)
# Out:
# pandas.core.frame.DataFrame

# %%
stand_data.head()
# Out:
#    icecream_sales  iced_coffee_sales  summer_months      temps
# 0    25649.780754       28592.182276              0  28.593141
# 1    32694.928923       37152.842623              0  37.130641
# 2    26467.798121       24074.193453              0  24.111898
# 3    43438.793949       49169.465998              0  49.218075
# 4    52452.628396       47249.399498              0  47.257661

# %%
import scipy
import matplotlib.pyplot as plt 
from statsmodels.formula.api import ols
import seaborn as sns 

sns.scatterplot(x='temps', y='iced_coffee_sales', data=stand_data)
# Out:
# <AxesSubplot: xlabel='temps', ylabel='iced_coffee_sales'>

# %%
print(ols('icecream_sales ~ temps', data=stand_data).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         icecream_sales   R-squared:                       0.875
# Model:                            OLS   Adj. R-squared:                  0.875
# Method:                 Least Squares   F-statistic:                 1.684e+04
# Date:                Fri, 11 Aug 2023   Prob (F-statistic):               0.00
# Time:                        16:49:49   Log-Likelihood:                -25183.
# No. Observations:                2400   AIC:                         5.037e+04
# Df Residuals:                    2398   BIC:                         5.038e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -6169.8442    531.506    -11.608      0.000   -7212.103   -5127.585
# ...

# %%
#intercept 절편
